# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroJacovac/dio-analise-dados-com-python-e-pandas/blob/main/Popula%C3%A7%C3%A3o_Mundial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Importando Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 2) Lendo os Arquivos

# %%
df = pd.read_csv("/content/drive/MyDrive/Dataset/world_population.csv")
display(df)
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %% [markdown]
# 3) Visualizar as 5 primeiras linhas

# %%
df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df = df.rename(columns={"CCA3":"Codigo Pais", "Country":"Pais", "Continent": "Continente", "Density (per km²)": "Desidade/km²", "Growth Rate": "Taxa Crescimento", "World Population Percentag": "% Pop. Mundial"})
display(df)
# Out:
#      Rank Codigo Pais               Pais           Capital Continente  \
# 0      36         AFG        Afghanistan             Kabul       Asia
# 1     138         ALB            Albania            Tirana     Europe
# 2      34         DZA            Algeria           Algiers     Africa
# 3     213         ASM     American Samoa         Pago Pago    Oceania
# 4     203         AND            Andorra  Andorra la Vella     Europe
# ..    ...         ...                ...               ...        ...
# 229   226         WLF  Wallis and Futuna          Mata-Utu    Oceania
# 230   172         ESH     Western Sahara          El Aaiún     Africa
# 231    46         YEM              Yemen             Sanaa       Asia
# 232    63         ZMB             Zambia            Lusaka     Africa
# 233    74         ZWE           Zimbabwe            Harare     Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %%
df = df.rename(columns={"Taxa Cresciento": "Taxa Crescimento"})
display(df)
# Out:
#      Rank Codigo Pais               Pais           Capital Continente  \
# 0      36         AFG        Afghanistan             Kabul       Asia
# 1     138         ALB            Albania            Tirana     Europe
# 2      34         DZA            Algeria           Algiers     Africa
# 3     213         ASM     American Samoa         Pago Pago    Oceania
# 4     203         AND            Andorra  Andorra la Vella     Europe
# ..    ...         ...                ...               ...        ...
# 229   226         WLF  Wallis and Futuna          Mata-Utu    Oceania
# 230   172         ESH     Western Sahara          El Aaiún     Africa
# 231    46         YEM              Yemen             Sanaa       Asia
# 232    63         ZMB             Zambia            Lusaka     Africa
# 233    74         ZWE           Zimbabwe            Harare     Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %%
df.head()
# Out:
#    Rank Codigo Pais            Pais           Capital Continente  \
# 0    36         AFG     Afghanistan             Kabul       Asia
# 1   138         ALB         Albania            Tirana     Europe
# 2    34         DZA         Algeria           Algiers     Africa
# 3   213         ASM  American Samoa         Pago Pago    Oceania
# 4   203         AND         Andorra  Andorra la Vella     Europe
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771         38972230         33753499         28189672
# 1          2842321          2866849          2882481          2913399
# 2         44903225         43451666         39543154         35856344
# 3            44273            46189            51368            54849
# 4            79824            77700            71746            71519
#
#    2000 Population  1990 Population  1980 Population  1970 Population  \
# 0         19542982         10694796         12486631         10752971
# ...

# %% [markdown]
# Total de Linhas e Colunas

# %%
df.shape
# Out:
# (234, 17)

# %%
df.columns
# Out:
# Index(['Rank', 'Codigo Pais', 'Pais', 'Capital', 'Continente',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Desidade/km²',
#        'Taxa Crescimento', 'World Population Percentage'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank                             int64
# Codigo Pais                     object
# Pais                            object
# Capital                         object
# Continente                      object
# 2022 Population                  int64
# 2020 Population                  int64
# 2015 Population                  int64
# 2010 Population                  int64
# 2000 Population                  int64
# 1990 Population                  int64
# 1980 Population                  int64
# 1970 Population                  int64
# Area (km²)                       int64
# Desidade/km²                   float64
# Taxa Crescimento               float64
# World Population Percentage    float64
# dtype: object

# %%
df.tail()
# Out:
#      Rank Codigo Pais               Pais   Capital Continente  \
# 229   226         WLF  Wallis and Futuna  Mata-Utu    Oceania
# 230   172         ESH     Western Sahara  El Aaiún     Africa
# 231    46         YEM              Yemen     Sanaa       Asia
# 232    63         ZMB             Zambia    Lusaka     Africa
# 233    74         ZWE           Zimbabwe    Harare     Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 229            11572            11655            12182            13142
# 230           575986           556048           491824           413296
# 231         33696614         32284046         28516545         24743946
# 232         20017675         18927715         16248230         13792086
# 233         16320537         15669666         14154937         12839771
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 229            14723            13454            11315             9377
# ...

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
df["Continente"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America'], dtype=object)

# %%
SouthAmerica = df.loc[df["Continente"] == "South America"]
SouthAmerica.head()
# Out:
#     Rank Codigo Pais       Pais       Capital     Continente  2022 Population  \
# 8     33         ARG  Argentina  Buenos Aires  South America         45510318
# 24    80         BOL    Bolivia         Sucre  South America         12224110
# 27     7         BRA     Brazil      Brasilia  South America        215313498
# 40    65         CHL      Chile      Santiago  South America         19603733
# 42    28         COL   Colombia        Bogota  South America         51874024
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 8          45036032         43257065         41100123         37070774
# 24         11936162         11090085         10223270          8592656
# 27        213196304        205188205        196353492        175873720
# 40         19300315         17870124         17004162         15351799
# 42         50930662         47119728         44816108         39215135
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.groupby("Continente")["Pais"].nunique()
# Out:
# Continente
# Africa           57
# Asia             50
# Europe           50
# North America    40
# Oceania          23
# South America    14
# Name: Pais, dtype: int64

# %%
df.groupby("Pais")["Taxa Crescimento"].mean()
# Out:
# Pais
# Afghanistan          1.0257
# Albania              0.9957
# Algeria              1.0164
# American Samoa       0.9831
# Andorra              1.0100
#                       ...
# Wallis and Futuna    0.9953
# Western Sahara       1.0184
# Yemen                1.0217
# Zambia               1.0280
# Zimbabwe             1.0204
# Name: Taxa Crescimento, Length: 234, dtype: float64

# %%
df["World Population Percentage"].mean()
# Out:
# 0.42705128205128207

# %%
df["World Population Percentage"].sum()
# Out:
# 99.93
